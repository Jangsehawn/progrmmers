# %%
#   **                 3   2
# *   *                1   3   1
#    *                 3  1 
#   *                  2  1
# *                       1 

for i in range(5):
    for j in range(1):
        if i==1:
            print('*',end=' ')
            print(' '*(3-i),'*')
        elif i==0:
            print(' ',end=' ')
            print('*'*2)
        else:
            print(' '*(5-i),'*')
# Out:
#   **
# *    *
#     *
#    *
#   *

# %%
# 완벽한 하트 만들기
#  ***    ****
#*     **     *
#*            * 
#  *        *
#    *    *
#      **


from pylab import *
x = linspace(-1.6, 1.6, 10000)
f = lambda x: (sqrt(cos(x)) * cos(200 * x) + sqrt(abs(x)) - 0.7) * \
pow((4 - x * x), 0.01)
plot(x, list(map(f, x)))
show()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in sqrt
#   if sys.path[0] == '':

# %%
import matplotlib.pyplot as plt
from numpy import sin
from numpy import cos
 
x = np.linspace(-2, 2, 10000)
f = lambda x: np.sqrt(cos(x)) * cos(80 * x) + 0.5 * np.sqrt(abs(x))

plt.plot(x, f(x))
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in sqrt

# %%
import turtle 

t = turtle.Turtle()

wn = turtle.Screen()

wn.title("star")

wn.bgcolor("black")  #바탕화면 색상을 black 로 칠한다.

t.begin_fill()            #도형의 안을 색칠할 준비를 한다.

t.color("red")           #도형의 펜의 색상은 red 색상으로 준비한다.

t.left(45)                #펜의 각도를 왼쪽으로 45도 회전한다 

t.forward(200)         #200 만큼 전진한다

t.circle(73,221.37)     #반지름이 73 인 호를 221.37 만큼 그린다.   

t.left(180)               #펜의 각도를 왼쪽으로 180도 회전한다.

t.circle(73,221.37)     #반지름이 73 인 호를 221.37 만큼 그린다.

t.forward(200)         #200 만큼 전진한다

t.end_fill()

# %% [markdown]
# ![image.png](attachment:image.png)
